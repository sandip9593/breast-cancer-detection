# %%
import matplotlib.image as img
import matplotlib.pyplot as plt

# %%
imgs=img.imread("Screenshot 2023-08-24 202616.png")

# %%
print(imgs)
# Out:
# [[[0.84313726 0.79607844 0.7647059  1.        ]
#   [0.8980392  0.84705883 0.8156863  1.        ]
#   [0.8901961  0.8392157  0.80784315 1.        ]
#   ...
#   [0.8745098  0.83137256 0.80784315 1.        ]
#   [0.8666667  0.8235294  0.8        1.        ]
#   [0.85490197 0.8117647  0.7882353  1.        ]]
#
#  [[0.84705883 0.8        0.76862746 1.        ]
#   [0.8980392  0.84313726 0.8117647  1.        ]
#   [0.8901961  0.8392157  0.80784315 1.        ]
#   ...
#   [0.8666667  0.8235294  0.8        1.        ]
#   [0.8627451  0.81960785 0.79607844 1.        ]
#   [0.85882354 0.8156863  0.7921569  1.        ]]
#
#  [[0.8392157  0.7921569  0.7607843  1.        ]
#   [0.8862745  0.8352941  0.8039216  1.        ]
#   [0.8784314  0.827451   0.79607844 1.        ]
#   ...
#   [0.85490197 0.8117647  0.7882353  1.        ]
#   [0.8627451  0.81960785 0.79607844 1.        ]
#   [0.8666667  0.8235294  0.8        1.        ]]
#
#  ...
#
#  [[0.7176471  0.6431373  0.57254905 1.        ]
# ...

# %%
type(imgs)
# Out:
# numpy.ndarray

# %%
imgs.shape
# Out:
# (651, 752, 4)

# %%
imgplt=plt.imshow(imgs)
plt.show()

# %%
from PIL import Image

# %%
img1=Image.open("Screenshot 2023-08-24 202616.png")
img_resize=img1.resize((200,200))

# %%
img_resize.save("resize.png")

# %%
img2=Image.open("resize.png")
imgplot=plt.imshow(img2)
plt.show()

# %%
import cv2

# %%
img3=cv2.imread("Screenshot 2023-08-24 202616.png")
gray=cv2.cvtColor(img3,cv2.COLOR_RGB2GRAY)

# %%
cv2.imshow("",gray)
cv2.waitKey(1)
# Out:
# -1
